# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/shen-pc/Desktop/WORK/ITS/data/YC/questions_regroup2.csv')

# %%
df
# Out:
#       Unnamed: 0                            problem_id  \
# 0              0  ea821dec-57e8-11e7-b63a-23b648f28dcb
# 1              1  eab8f31c-57e8-11e7-b649-4b6596f57761
# 2              2  ec5889ee-57e8-11e7-b6c7-1380287a9714
# 3              3  ce3fb4ea-7cce-11e7-96b1-6fef97983905
# 4              4  eacaab3e-57e8-11e7-b64f-c365d1115185
# 5              5  ead9fd1e-57e8-11e7-b653-c7c8278d380e
# 6              6  eb519e28-57e8-11e7-b675-f7153d5aa171
# 7              7  eb551c10-57e8-11e7-b676-6741dcb28c64
# 8              8  eaa238d4-57e8-11e7-b644-dbc8a213a052
# 9              9  eaa9cf54-57e8-11e7-b645-b39c65f70a96
# 10            10  eaaded1e-57e8-11e7-b646-d7df109181f5
# 11            11  eab16d7c-57e8-11e7-b647-37fa89f7c77b
# 12            12  eab56cba-57e8-11e7-b648-fbb155c1b5c9
# 13            13  ea84c6b4-57e8-11e7-b63b-df18b29d7515
# 14            14  ea56fffe-57e8-11e7-b62b-5780c810cfd4
# 15            15  eb6eb45e-57e8-11e7-b67d-339da0ba0936
# ...

# %%
len(df)
# Out:
# 6152

# %%
df.iloc[3]['body']
# Out:
# '如图，Rt$\\triangle ABC$中，$\\angle ACB=90^\\circ$，$ABED$、$BCGF$、$ACIH$均为正方形，且面积分别为$S_1$、$S_2$、$S_3. $求证$BC^2+AC^2=AB^2$<div><img src="https://course.yangcong345.com/FuFUAj61w-qkBChuNUx2-0t75fuh?imageMogr2/thumbnail/300x300" /></div>'

# %%
raw =
