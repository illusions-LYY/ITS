# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/Users/shen-pc/Desktop/WORK/ITS/data/data_merge.csv',index_col='id')
data
# Out:
#                                                    body  \
# id
# 0     已知直角三角形的两条直角边长分别是$6$，$ \sqrt{10} $，则斜边长为（$\:\:...
# 1                                      $-3.782(\:\:\:)$
# 2     如图，$ \triangle ABC$中，$B ^\prime $、$C ^\prime $...
# 3     有一种投球游戏，将球投入下图所示的阴影区域记为“投中”，且投中一次得$20$分$.$狗蛋儿投...
# 4                     解方程$5(3x-1)-2(x-1)=49$，得$x=$____.
# 5     若定义：$f(a,b)=(-a,b)$，$g(m,n)=(-n,m)$ 例如：$f(1,2)...
# 6     关于$x$的一元二次方程$x^2+2x-(k-1)=0$的根的情况，下列说法正确的是（$\:...
# 7        一次函数$y=-3x-2$的图象向右平移$3$个单位后，新图象的解析式为（$\:\:\:$）
# 8     关于$x$的一元二次方程$3x^2-4x+(2a+1)=0$的根的情况，下列说法正确的是（$...
# 9     在四边形$ABCD$中， $ \angle B= \angle D=90 ^\circ $ ...
# 10    关于$x$的一元二次方程$x^2-2(m+1)x+m^2-7=0$的根的情况，下列说法正确的...
# 11    一个正数$x$的两个平方根分别为$5+a$和$3a-1$，则$a=$____；$x=$___...
# 12    在$直角三角形 ABC$中，$ \angle C=90 ^\circ $，$ \angle ...
# 13                     已知$a-b=3$，$ab=3$，则$(a+b)^2=$____
# 14    用配方法解关于$x$的一元二次方程  $x^2+2mx-n=0(n+m^2 \geqslan...
# 15    田豆花同学放学后从学校门口走路到公交站台，先坐公交到小区附近的站点，下公交车后遇见邻居聊了两...
# ...

# %% [markdown]
# merge:'goal_name,subsection,chapter,section'

# %%
yls = []
for i in range(len(data)):
    if data['merge'][i].split(',')[2] == '有理数':
        yls.append(data.iloc[i])
yls
# Out:
# [body                                         $-3.782(\:\:\:)$
#  explains    {"{\"body\": \"$-3.782$符号为负,是负数 \\n又是有限小数,是有理数...
#  merge                                        数的分类,有理数,有理数,有理数
#  Name: 1, dtype: object,
#  body        如果以每月生产$180$个零件为准，超过的零件数记作正数，不足的零件数记作负数，那么$1$月...
#  explains    {"{\"body\": \"“超过”与“不足”是以每月生产$180$个零件为准 \\n$ ...
#  merge                                正负数的实际意义,正数和负数,有理数,正数和负数
#  Name: 19, dtype: object,
#  body               除以一个不等于$0$的数，等于乘以这个数的倒数.这一法则可表示成$(\:\:\:)$
#  explains    {"{\"body\": \"有理数除法法则可以表示成：$p \\\\div q=p \\\...
#  merge                               有理数的除法,有理数的除法,有理数,有理数的乘除法
#  Name: 47, dtype: object,
#  body        已知一种运算$P \triangle Q= \frac{P+Q}{3} $，则$1 \tri...
#  explains    {"{\"body\": \"$ \\\\because $新运算的规则是：$P \\\\t...
#  merge                                     定义新运算,乘方,有理数,有理数的乘方
#  Name: 56, dtype: object,
#  body                      计算$-3.6+(- \frac{1}{2})+(-3)=$____.
# ...

# %%
yls_df = pd.DataFrame(yls)

# %%
yls_df[['goal_name','subsection','chapter','section']] = yls_df['merge'].str.split(',',expand=True)

# %%
yls_df
# Out:
#                                                    body  \
# 1                                      $-3.782(\:\:\:)$
# 19    如果以每月生产$180$个零件为准，超过的零件数记作正数，不足的零件数记作负数，那么$1$月...
# 47           除以一个不等于$0$的数，等于乘以这个数的倒数.这一法则可表示成$(\:\:\:)$
# 56    已知一种运算$P \triangle Q= \frac{P+Q}{3} $，则$1 \tri...
# 73                  计算$-3.6+(- \frac{1}{2})+(-3)=$____.
# 105                          若$|a|+a=0$，则$a$是$(\:\:\:)$
# 111                计算$-1.2+(- \frac{1}{5} )+(-5)=$____.
# 134   仔细思考以下各对量： ①胜二局与负三局 ②气温上升$3$℃与气温下降$3$℃ ③盈利$5$万...
# 148   如果$6\text{m}$表示水位升高$6\text{m}$，那么$-2\text{m}$表...
# 167                       如果$a$，$b$互为相反数，则$a+b=$____$.$
# 178   下列化简$(-3.6) \div (- \frac{3}{4} )$的过程正确的是$(\:\...
# 185   下列化简$(-2.4) \div (- \frac{3}{8} )$的过程正确的是$(\:\...
# 264                             在数轴上，原点及原点右边的点表示的数是====
# 278   $-10^2 \div  \frac{1}{2}  \times  \frac{2}{5} ...
# 285   用科学记数法把$320\:000$写成$a \times 10^n$，其中$a$是____，...
# 300                $- 10\:140\:000$可用科学记数法表示为$(\:\:\:)$
# ...

# %%
ppp = yls_df.sort_values(by='subsection')

# %%
ppp
# Out:
#                                                    body  \
# 1914  有一列数依次为：$ \frac{4}{9}$、$ \frac{12}{11}$、$ \fra...
# 5579  仔细观察下面的图案：$\star \perp \circ \#  \ast \star  \...
# 2549  如图，$OA$、$OB$、$OC$、$OD$、$OE$是平面内有公共端点的五条射线，从射线$...
# 4643  有一列数依次为：$2$、$10$、$50$、$250 \cdots $请根据规律写出该列数的...
# 4615  有一列数依次为：$2$、$6$、$18$、$54$、$162 \cdots $请根据规律写出...
# 3252  有一列数：$2$，$7$，$13$，$20$，$x$，$37$，$\cdots\cdots$...
# 4612  有一列数依次为：$90$、$87$、$84$、$81$、$78 \cdots $请根据规律写...
# 1210             下边各图形之间都有相同的规律.    根据这种规律， $m$的值是____.
# 1187  如图，$OA$、$OB$、$OC$、$OD$、$OE$是平面内有公共端点的五条射线，从射线$...
# 4448                       数表如下图，则第$6$行第$8$列的数是____
# 3185  观察下列一组数的排列：$1$，$2$，$3$，$4$，$5$，$4$，$3$，$2$，$1$...
# 3183                       数表如下图，则第$1$行第$9$列的数是____
# 3180                      数表如下图，则第$1$行第$10$列的数是____
# 4835  有一列数依次为$ \frac{1}{3} $、$ \frac{3}{10} $、 $ \fr...
# 3176  天鹅座第$61$颗暗星距离地球约$102\:000\:000\:000\:000$千米，如果...
# 3172  用科学记数法把$16\:000$写成$a \times 10^n$，其中$a$是____，$...
# ...

# %%
ppp.subsection.unique()
# Out:
# array(['', '乘方', '数轴', '有理数', '有理数的乘法', '有理数的减法', '有理数的加法', '有理数的除法',
#        '正数和负数', '相反数', '绝对值'], dtype=object)

# %%
from gensim.test.utils import common_texts
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(common_texts)]
model = Doc2Vec(documents, vector_size=5, window=2, min_count=1, workers=4)

# %%
common_texts
# Out:
# [['human', 'interface', 'computer'],
#  ['survey', 'user', 'computer', 'system', 'response', 'time'],
#  ['eps', 'user', 'interface', 'system'],
#  ['system', 'human', 'system', 'eps'],
#  ['user', 'response', 'time'],
#  ['trees'],
#  ['graph', 'trees'],
#  ['graph', 'minors', 'trees'],
#  ['graph', 'minors', 'survey']]

# %%
documents
# Out:
# [TaggedDocument(words=['human', 'interface', 'computer'], tags=[0]),
#  TaggedDocument(words=['survey', 'user', 'computer', 'system', 'response', 'time'], tags=[1]),
#  TaggedDocument(words=['eps', 'user', 'interface', 'system'], tags=[2]),
#  TaggedDocument(words=['system', 'human', 'system', 'eps'], tags=[3]),
#  TaggedDocument(words=['user', 'response', 'time'], tags=[4]),
#  TaggedDocument(words=['trees'], tags=[5]),
#  TaggedDocument(words=['graph', 'trees'], tags=[6]),
#  TaggedDocument(words=['graph', 'minors', 'trees'], tags=[7]),
#  TaggedDocument(words=['graph', 'minors', 'survey'], tags=[8])]

# %%
vector = model.infer_vector(["system", "response"])

# %%
vector
# Out:
# array([-0.01519612,  0.08389594, -0.02690305,  0.09432001,  0.05190121],
#       dtype=float32)

# %%
sss = 'human interface computer'

# %%
model.vocabulary

# %%
for i in range(9):
    print(model.docvecs[i])
# Out:
# [ 0.01957394 -0.04352891  0.01151429 -0.07564452 -0.09589833]
# [-0.04559866  0.07477349  0.01417593 -0.07347184  0.02556597]
# [ 0.05713726 -0.09597804  0.03329236  0.01998447 -0.05379698]
# [ 0.0928795  -0.02861902  0.01968862 -0.05019694  0.05132913]
# [-0.02776747  0.08597849  0.09722327 -0.05988003  0.0174726 ]
# [ 0.00773704  0.04519016 -0.01517135 -0.0546782   0.05898836]
# [ 0.08909235 -0.02025969  0.06551914  0.02119997 -0.02918315]
# [-0.06155676  0.08868406 -0.07165428 -0.07436979  0.09846402]
# [0.01515704 0.06550371 0.06401108 0.04028419 0.00267623]

# %%
model.docvecs.distance(0,3)
# Out:
# 0.8656472563743591

# %%
model.docvecs.most_similar(1)
# Out:
# [(4, 0.8043986558914185),
#  (7, 0.776969850063324),
#  (5, 0.7530813217163086),
#  (8, 0.1860945224761963),
#  (0, -0.056532710790634155),
#  (3, -0.07584896683692932),
#  (6, -0.4990019202232361),
#  (2, -0.7928260564804077)]

# %%
res = []
for i in range(9):
    res.append((i,model.docvecs.distance(1,i)))
sorted(res,key=lambda x:x[1])
# Out:
# [(1, 0.0),
#  (4, 0.19560134410858154),
#  (7, 0.22303014993667603),
#  (5, 0.2469186782836914),
#  (8, 0.8139055222272873),
#  (0, 1.056532770395279),
#  (3, 1.0758489966392517),
#  (6, 1.499001920223236),
#  (2, 1.7928260564804077)]

# %%
model.docvecs.closer_than(1,2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-128-48a72def82d8> in <module>
# ----> 1 model.docvecs.closer_than(1,2)
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/keyedvectors.py in closer_than(self, entity1, entity2)
#     359         """Get all entities that are closer to `entity1` than `entity2` is to `entity1`."""
#     360         all_distances = self.distances(entity1)
# --> 361         e1_index = self.vocab[entity1].index
#     362         e2_index = self.vocab[entity2].index
#     363         closer_node_indices = np.where(all_distances < all_distances[e2_index])[0]
#
# KeyError: 1

# %%
model.docvecs.similarity(1,2),model.docvecs.distance(1,2)
# Out:
# (-0.79282606, 1.7928260564804077)

# %%
model.docvecs.similarity(1,3),model.docvecs.distance(1,3)
# Out:
# (-0.075849, 1.0758489966392517)

# %%
14824+30000-1450
# Out:
# 43374

# %%
841**2
# Out:
# 707281
